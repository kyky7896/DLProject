# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.5.18.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
#      <input type="file" id="files-a67b25a4-ab9a-4c4c-b714-5cae1e6d2e84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a67b25a4-ab9a-4c4c-b714-5cae1e6d2e84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kyky7896","key":"dbe11208a425010496b2ff560a0f5c37"}'}

# %%
ls -1ha kaggle.json
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning이 발생하지 않도록 해줍니다.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.28G/2.29G [00:15<00:00, 191MB/s]
# 100% 2.29G/2.29G [00:15<00:00, 161MB/s]

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
import torch # 파이토치 기본 라이브러리 
import torchvision # 이미지 관련 된 파이토치 라이브러리
from torchvision import datasets # 토치비전에서 제공하는 데이터셋
from torchvision import transforms # 이미지 전처리 기능들을 제공하는 라이브러리
from torch.utils.data import DataLoader # 데이터를 모델에 사용할 수 있도록 적재해 주는 라이브러리
from torch.utils.data import random_split
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import Dataset
import glob
from PIL import Image
import cv2
from torchsummary import summary

# %%
# !ls
# Out:
# chest-xray-pneumonia.zip  kaggle.json  sample_data

# %%
# !unzip chest-xray-pneumonia.zip -d chest/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: chest/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0441-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0442-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0444-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0445-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0446-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0447-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0448-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0449-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0450-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0451-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0452-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0453-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0453-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0455-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0456-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0457-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0458-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0459-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0460-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0461-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0463-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0464-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0465-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0466-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0467-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0467-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0467-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0469-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0471-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0472-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0473-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0474-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0475-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0476-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0477-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0478-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0479-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0480-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0481-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0482-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0483-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0484-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0485-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0486-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0487-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0488-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0489-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0490-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0491-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0491-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0492-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0493-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0494-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0495-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0496-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0497-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0497-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0499-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0499-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0499-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0500-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0501-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0501-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0501-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0502-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0503-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0504-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0505-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0505-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0505-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0506-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0507-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0508-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0509-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0509-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0509-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0510-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0511-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0511-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0511-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0512-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0513-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0514-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0515-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0516-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0517-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0517-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0519-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0519-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0519-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0520-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0521-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0522-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0523-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0523-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0523-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0524-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0525-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0525-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0526-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0527-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0528-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0529-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0530-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0531-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0531-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0532-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0533-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0533-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0533-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0534-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0535-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0536-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0537-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0538-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0539-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0539-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0539-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0540-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0541-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0542-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0543-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0543-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0544-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0545-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0545-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0545-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0546-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0547-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0548-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0549-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0549-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0549-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0551-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0551-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0551-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0552-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0553-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0553-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0553-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0554-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0555-0001-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0555-0001-0002.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0555-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0556-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0557-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0559-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0560-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0561-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0562-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0563-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0564-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0565-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0566-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0568-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0569-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0570-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0571-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0574-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0575-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0577-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0578-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0579-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0580-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-0581-0001.jpeg
#   inflating: chest/chest_xray/train/NORMAL/IM-
jpeg
#   inflating: chest/chest_xray/train/PNEUMONIA/person9_bacteria_40.jpeg
#   inflating: chest/chest_xray/train/PNEUMONIA/person9_bacteria_41.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
#   inflating: chest/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1946_bacteria_4875.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1947_bacteria_4876.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1949_bacteria_4880.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1951_bacteria_4882.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1952_bacteria_4883.jpeg
#   inflating: chest/chest_xray/val/PNEUMONIA/person1954_bacteria_4886.jpeg

# %%
data_dir="./chest/"

# %%
# !nvidia-smi
# Out:
# Thu May 26 13:02:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## 데이터 불러오기

# %%
# # option 1 : google drive에서 데이터 copy
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !cp "/content/drive/MyDrive/CNN/Chest.zip" "./"
# !unzip Chest.zip -d chest/
# data_dir = "./chest/"

# %%
# data_dir="../input/chest-xray-pneumonia/"

# %%
## we cal also use the mean and std of ImageNet dataset ie mean=[0.485, 0.456, 0.406] and std =[0.229, 0.224, 0.225]     
train_transform = transforms.Compose([transforms.ToTensor(), 
                                        transforms.Resize([256,256]),
                                        transforms.ColorJitter(brightness=0.2, contrast=0.3)])
test_trainsform = transforms.Compose([transforms.ToTensor(),
                                        transforms.Resize([256,256])])

# %%
trainset=datasets.ImageFolder(data_dir + "chest_xray/train/", transform=train_transform)
testset=datasets.ImageFolder(data_dir + "chest_xray/test/",transform=test_trainsform)
valid=datasets.ImageFolder(data_dir + "chest_xray/val/",transform=test_trainsform)

# %%
print(type(trainset), type(testset), type(valid))
print(len(trainset), len(testset), len(valid))
# Out:
# <class 'torchvision.datasets.folder.ImageFolder'> <class 'torchvision.datasets.folder.ImageFolder'> <class 'torchvision.datasets.folder.ImageFolder'>
# 5216 624 16

# %%
dataset_size = len(trainset)
train_size = int(dataset_size * 0.75)
valid_size = int(dataset_size-train_size)

# %%
trainset, validset = random_split(trainset, [train_size, valid_size])

# %%
validset=valid+validset

# %%
print(type(trainset), len(trainset))
print(type(validset), len(validset))
print(type(testset), len(testset))
# Out:
# <class 'torch.utils.data.dataset.Subset'> 3912
# <class 'torch.utils.data.dataset.ConcatDataset'> 1320
# <class 'torchvision.datasets.folder.ImageFolder'> 624

# %%
type(trainset[0][0]), type(trainset[0][1])
# Out:
# (torch.Tensor, int)

# %%
# trainset[0][0].size() 
# 1 x 28 x 28 : channels x height x width
# 일반적으로(openCV 등에서는) 이미지가 height x width x channels 로 크기가 표현
# 그러나 파이토치에서는 이미지 한장이 channels x height x width 표시됨을 유의
trainset[0][0].size() # trainset[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %% [markdown]
# ## 데이터 시각화

# %%
img = trainset[2][0]
#img = img * 0.5 + 0.5 #unnormalize (normalize : (data - 0.5)/0.5))
plt.imshow(img.permute(1, 2, 0))

# %%
trainset[2][1] #0번 : 폐렴아님 , 1번 : 폐렴임
# Out:
# 1

# %%
figure, axes = plt.subplots(figsize=(22, 6), nrows=1, ncols=8)
for i in range(8):
  # axes[i].imshow(trainset[i][0].permute(1, 2, 0))
  img = trainset[i][0]
  #img = img * 0.5 + 0.5 # unnormalize (normalize : (data - 0.5)/0.5))
  axes[i].imshow(img.permute(1, 2, 0))

# %%
labels_map = {0 : 'normal', 1 : 'pneumonia'}

fig = plt.figure(figsize=(16, 16))
columns = 4
rows = 5

for i in range(1,columns*rows +1):
  rnd_idx = np.random.randint(len(trainset))
  img = trainset[rnd_idx][0].permute(1, 2, 0) 
  # img = img * 0.5 + 0.5 # unnormalize (normalize : (data - 0.5)/0.5))
  fig.add_subplot(rows, columns, i)
  plt.imshow(img)
  # 정답 :trainset[rnd_idx][1] - 정수
  plt.title(labels_map[trainset[rnd_idx][1]])
  plt.axis("off")

# %% [markdown]
# ## 데이터 적재

# %%
# 파이토치는 데이터를 셔플하거나, 병렬로 데이터를 부르거나,혹은 배치 작업을 
# torch.utils.data.DataLoader 를 통해서 도와줌
batch_size = 16 # 중요한 하이퍼 파라미터, 16 이하로 사용하는것이 성능에 좋다고 알려져 있음
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True) # 훈련용
validloader = DataLoader(validset, batch_size=batch_size, shuffle=False) # 검증용
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False) # 테스트용

# %%
print(type(trainloader), len(trainloader))
print(type(validloader), len(validloader))
print(type(testloader), len(testloader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'> 245
# <class 'torch.utils.data.dataloader.DataLoader'> 83
# <class 'torch.utils.data.dataloader.DataLoader'> 39

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(images.shape, labels.shape)
# Out:
# torch.Size([16, 3, 256, 256]) torch.Size([16])

# %%
def imshow(img):         
    #img = img * 0.5 + 0.5 #unnormalize (normalize : (data - 0.5)/0.5))
    plt.figure(figsize=(20, 200))
    plt.imshow(img.permute(1, 2, 0))

dataiter = iter(trainloader)
images, labels = dataiter.next() # 32개의 image, 32개의 label

imshow(torchvision.utils.make_grid(images, nrows=8))

# %% [markdown]
# ## 모델 생성 (VGGnet)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from torch import nn
from torch import optim
import torch.nn.functional as F

# %%
# class VGG16(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.block1 = nn.Sequential(
#             nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(64),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(64),
#             nn.LeakyReLU(),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         self.block2 = nn.Sequential(
#             nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(128),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(128),
#             nn.LeakyReLU(),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         self.block3 = nn.Sequential(
#             nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(256),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(256),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(256),
#             nn.LeakyReLU(),            
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )    

#         self.block4 = nn.Sequential(
#             nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),            
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )   

#         self.block5 = nn.Sequential(
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
#             nn.BatchNorm2d(512),
#             nn.LeakyReLU(),            
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )  # 512 * 7 * 7
        
#         self.avgpool = nn.AvgPool2d(7, 7)

#         self.classifier = nn.Sequential(            
#             nn.Linear(in_features=512, out_features=64),             
#             nn.LeakyReLU(),                     
#             nn.Dropout(0.3),
#             nn.Linear(in_features=64, out_features=2),            
#         )
       
#     def forward(self, x):
#         x = self.block1(x)
#         x = self.block2(x)
#         x = self.block3(x)
#         x = self.block4(x)
#         x = self.block5(x)
#         x = self.avgpool(x)
#         #x = x.view(-1, 512)
#         x = torch.flatten(x, 1) # 1번 dim부터 펼침
#         x = self.classifier(x)
#         return x

# %%
# !pip install efficientnet-pytorch==0.7.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet-pytorch==0.7.1
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.7.1) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (4.2.0)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=580155ff318b01689eec86d421a493ccad27338433244275fdd35fc86c040c40
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
from efficientnet_pytorch import EfficientNet
#모델 생성
efficientNet=EfficientNet.from_pretrained('efficientnet-b0', num_classes=2)
model=efficientNet.to(device)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b0

# %%
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          ZeroPad2d-1          [-1, 3, 225, 225]               0
# Conv2dStaticSamePadding-2         [-1, 32, 112, 112]             864
#        BatchNorm2d-3         [-1, 32, 112, 112]              64
# MemoryEfficientSwish-4         [-1, 32, 112, 112]               0
#          ZeroPad2d-5         [-1, 32, 114, 114]               0
# Conv2dStaticSamePadding-6         [-1, 32, 112, 112]             288
#        BatchNorm2d-7         [-1, 32, 112, 112]              64
# MemoryEfficientSwish-8         [-1, 32, 112, 112]               0
#           Identity-9             [-1, 32, 1, 1]               0
# Conv2dStaticSamePadding-10              [-1, 8, 1, 1]             264
# MemoryEfficientSwish-11              [-1, 8, 1, 1]               0
#          Identity-12              [-1, 8, 1, 1]               0
# Conv2dStaticSamePadding-13             [-1, 32, 1, 1]             288
#          Identity-14         [-1, 32, 112, 112]               0
# Conv2dStaticSamePadding-15         [-1, 16, 112, 112]             512
#       BatchNorm2d-16         [-1, 16, 112, 112]              32
#       MBConvBlock-17         [-1, 16, 112, 112]               0
#          Identity-18         [-1, 16, 112, 112]               0
# Conv2dStaticSamePadding-19         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-20         [-1, 96, 112, 112]             192
# MemoryEfficientSwish-21         [-1, 96, 112, 112]               0
#         ZeroPad2d-22         [-1, 96, 113, 113]               0
# Conv2dStaticSamePadding-23           [-1, 96, 56, 56]             864
#       BatchNorm2d-24           [-1, 96, 56, 56]             192
# MemoryEfficientSwish-25           [-1, 96, 56, 56]               0
#          Identity-26             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-27              [-1, 4, 1, 1]             388
# MemoryEfficientSwish-28              [-1, 4, 1, 1]               0
#          Identity-29              [-1, 4, 1, 1]               0
# Conv2dStaticSamePadding-30             [-1, 96, 1, 1]             480
#          Identity-31           [-1, 96, 56, 56]               0
# Conv2dStaticSamePadding-32           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-33           [-1, 24, 56, 56]              48
#       MBConvBlock-34           [-1, 24, 56, 56]               0
#          Identity-35           [-1, 24, 56, 56]               0
# Conv2dStaticSamePadding-36          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-37          [-1, 144, 56, 56]             288
# MemoryEfficientSwish-38          [-1, 144, 56, 56]               0
#         ZeroPad2d-39          [-1, 144, 58, 58]               0
# Conv2dStaticSamePadding-40          [-1, 144, 56, 56]           1,296
# MemoryEfficientSwish-242           [-1, 1152, 7, 7]               0
#        ZeroPad2d-243         [-1, 1152, 11, 11]               0
# Conv2dStaticSamePadding-244           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-245           [-1, 1152, 7, 7]           2,304
# MemoryEfficientSwish-246           [-1, 1152, 7, 7]               0
#         Identity-247           [-1, 1152, 1, 1]               0
# Conv2dStaticSamePadding-248             [-1, 48, 1, 1]          55,344
# MemoryEfficientSwish-249             [-1, 48, 1, 1]               0
#         Identity-250             [-1, 48, 1, 1]               0
# Conv2dStaticSamePadding-251           [-1, 1152, 1, 1]          56,448
#         Identity-252           [-1, 1152, 7, 7]               0
# Conv2dStaticSamePadding-253            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-254            [-1, 192, 7, 7]             384
#      MBConvBlock-255            [-1, 192, 7, 7]               0
#         Identity-256            [-1, 192, 7, 7]               0
# Conv2dStaticSamePadding-257           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-258           [-1, 1152, 7, 7]           2,304
# MemoryEfficientSwish-259           [-1, 1152, 7, 7]               0
#        ZeroPad2d-260           [-1, 1152, 9, 9]               0
# Conv2dStaticSamePadding-261           [-1, 1152, 7, 7]          10,368
#      BatchNorm2d-262           [-1, 1152, 7, 7]           2,304
# MemoryEfficientSwish-263           [-1, 1152, 7, 7]               0
#         Identity-264           [-1, 1152, 1, 1]               0
# Conv2dStaticSamePadding-265             [-1, 48, 1, 1]          55,344
# MemoryEfficientSwish-266             [-1, 48, 1, 1]               0
#         Identity-267             [-1, 48, 1, 1]               0
# Conv2dStaticSamePadding-268           [-1, 1152, 1, 1]          56,448
#         Identity-269           [-1, 1152, 7, 7]               0
# Conv2dStaticSamePadding-270            [-1, 320, 7, 7]         368,640
#      BatchNorm2d-271            [-1, 320, 7, 7]             640
#      MBConvBlock-272            [-1, 320, 7, 7]               0
#         Identity-273            [-1, 320, 7, 7]               0
# Conv2dStaticSamePadding-274           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-275           [-1, 1280, 7, 7]           2,560
# MemoryEfficientSwish-276           [-1, 1280, 7, 7]               0
# AdaptiveAvgPool2d-277           [-1, 1280, 1, 1]               0
#          Dropout-278                 [-1, 1280]               0
#           Linear-279                    [-1, 2]           2,562
# ================================================================
# Total params: 4,010,110
# Trainable params: 4,010,110
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 212.79
# Params size (MB): 15.30
# Estimated Total Size (MB): 228.66
# ----------------------------------------------------------------

# %% [markdown]
# ## 모델 컴파일

# %%
learning_rate = 0.0001
criterion = nn.CrossEntropyLoss() # 손실함수
# optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9) # 옵티마이저 : Momentum
# optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.001) # 규제의 강도 : weight_decay=0.001
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.001)

# %%
# Learning Rate Schedule
# https://pytorch.org/docs/stable/generated/torch.optim.lr_scheduler.ReduceLROnPlateau.html

# monitoring 하고 있는 값(test_loss)이 patience 기간동안(onPlateau) 줄어들지 않을때  lr에 factor(0.1)를 곱해줌
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", patience=7, factor=0.1, verbose=True)

# %% [markdown]
# ## 모델 훈련

# %%
# from torch.utils.tensorboard import SummaryWriter
# writer = SummaryWriter()

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

def validation(model, testloader, criterion):
#     test_accuracy = 0
    test_loss = 0
    preds_list=[]
    true_list=[]
    
    with torch.no_grad(): # 예측에는 gradient가 필요 없음
        for images, labels in testloader: # 1 iteration마다 배치 단위로 image와 label을 가져옴
            images, labels = images.to(device), labels.to(device) # data를 GPU로 보내기
            # Not Flatten!!!
            #images.resize_(images.shape[0], 784) # batch size x 784
            
            logits = model.forward(images) # 입력 : batch_size, 28, 28
            
            loss = criterion(logits, labels)
            test_loss += loss.item()

            probs = F.softmax(logits.cpu(), dim=1)
            _, preds = torch.max(probs, 1) # preds = probs.max(dim=1)[1]
#             correct = (preds == labels).sum()
#             accuracy = correct / images.shape[0]
#             test_accuracy += accuracy

   
            labels=labels.cpu()
            preds_list.extend(preds)
            true_list.extend(labels)

        # 평가지표 계산    
        val_accuracy = accuracy_score(true_list, preds_list)
        val_recall = recall_score(true_list, preds_list)
        val_f1_score = f1_score(true_list, preds_list)
        
                
    return val_accuracy, val_recall, val_f1_score, test_loss

# %%
def train(model, epochs, criterion, optimizer):
    steps = 0
    # 1 에폭(epoch)당 반복수
    #iter_per_epoch = len(trainset) / batch_size
    iter_per_epoch = len(trainloader)
    print_every = iter_per_epoch
    best_f1_score = 0.7

    # for Early stopping
    min_loss = 1000
    trigger = 0
    patience = 8 # monitoring 하는 test loss가 더이상 줄지 않는 횟수를 몇번이나 참을지..
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for images, labels in iter(trainloader): #iterator에서 batch_size씩 가져와 images와 labels에 전달
            steps += 1
            images, labels = images.to(device), labels.to(device) # data를 GPU로 보내기
            # not Flatten!!
            # images.resize_(images.size()[0], 784)
            optimizer.zero_grad()

            # 1. Forward (Loss 얻게됨)
            output = model.forward(images)
            loss = criterion(output, labels)

            # 2. Backward (Gradient가 오차역전파로 구해짐)
            loss.backward()

            # 3. Gradient Descent (Model parameter update) :  W <- W-lr*Gradient
            optimizer.step()
            train_loss += loss.item() # 1 epoch 당 누적된 로스
            if steps % print_every == 0 :
                model.eval() # 배치 정규화, 드롭아웃 이 적용될 경우 model.forward 연산이 training 때와 다르므로 반드시 설정
                val_accuracy, val_recall, val_f1_score, val_loss = validation(model, validloader, criterion)
                #train_accuracy, train_recall, train_f1_score, train_loss = validation(model, trainloader, criterion)

                # writer.add_scalar("Loss/train", train_loss/len(trainloader), epoch)
                # writer.add_scalar("Loss/test", valid_loss/len(validloader), epoch)
                # writer.add_scalars("Loss/train and valid",
                #                   { "train" : train_loss/len(trainloader),
                #                     "test" : valid_loss/len(validloader) }, epoch)

                print("Epoch : {}/{}...".format(epoch+1, epochs),
                      " Train Loss : {:.3f}".format(train_loss/len(trainloader) ),
                      " Valid Recall : {:.3f}".format(val_recall),
                      " Valid Accuracy : {:.3f}".format(val_accuracy),
                      " Valid F1_score : {:.3f}".format(val_f1_score)
                      # " Train Recall : {:.3f}".format(train_recall),
                      # " Train Accuracy : {:.3f}".format(train_accuracy),
                      # " Train F1_score : {:.3f}".format(train_f1_score)
                     )
                
                # Best model 저장
                if val_f1_score > best_f1_score:
                    torch.save(model.state_dict(), "best_checkpoint.pth")
                    best_f1_score = val_f1_score

                # Early stopping Start
                if val_loss > min_loss:
                    trigger +=1
                    print("trigger :", trigger)
                    if trigger > patience:
                        print("Early Stopping!!!")
                        print("Train step is finished!!")
                        # writer.flush()
                        return
                else:
                    min_loss = val_loss
                    trigger = 0
                    # print("min loss set to current valid loss!!!")

                # Early stopping End
                train_loss = 0
                model.train()

                # Learning Rate Scheduler
                scheduler.step(val_loss)
    # writer.flush()

# %%
train(model, 30, criterion, optimizer)
# Out:
# Epoch : 1/30...  Train Loss : 0.179  Valid Recall : 1.000  Valid Accuracy : 0.756  Valid F1_score : 0.858
# Epoch : 2/30...  Train Loss : 0.051  Valid Recall : 0.999  Valid Accuracy : 0.916  Valid F1_score : 0.946
# Epoch : 3/30...  Train Loss : 0.039  Valid Recall : 0.977  Valid Accuracy : 0.981  Valid F1_score : 0.987

# %%
# writer.close()

# %% [markdown]
# ## 평가

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

def evaluate(model, testloader):
#     test_accuracy = 0
    test_loss = 0
    preds_list=[]
    true_list=[]
    
    with torch.no_grad(): # 예측에는 gradient가 필요 없음
        for images, labels in testloader: # 1 iteration마다 배치 단위로 image와 label을 가져옴
            images, labels = images.to(device), labels.to(device) # data를 GPU로 보내기
            # Not Flatten!!!
            #images.resize_(images.shape[0], 784) # batch size x 784
            
            logits = model.forward(images) # 입력 : batch_size, 28, 28
            
            loss = criterion(logits, labels)
            test_loss += loss.item()

            probs = F.softmax(logits.cpu(), dim=1)
            _, preds = torch.max(probs, 1) # preds = probs.max(dim=1)[1]
#             correct = (preds == labels).sum()
#             accuracy = correct / images.shape[0]
#             test_accuracy += accuracy

   
            labels=labels.cpu()
            preds_list.extend(preds)
            true_list.extend(labels)

        # 평가지표 계산    
        val_accuracy = accuracy_score(true_list, preds_list)
        val_recall = recall_score(true_list, preds_list)
        val_f1_score = f1_score(true_list, preds_list)
        
                
    print("test_accuracy : ", val_accuracy)
    print("test_recall : ", val_recall)
    print("test_f1_score : ", val_f1_score)

# %%
# 마지막 학습결과를 저장 후 나중에 사용하기 원할 때
torch.save(model.state_dict(), "last_checkpoint.pth")
state_dict = torch.load("last_checkpoint.pth") 
last_model = model # 이미 model에 마지막 학습결과가 있으나 last_model로 다시 불러옴
last_model.to(device)
last_model.load_state_dict(state_dict) # model과 parameter를 매치 시키는 작업
evaluate(last_model, testloader)

# %%
# f1_score 0.7이상 기준으로 가장 높을때의 모델 파라미터가 저장되어 있음
state_dict = torch.load("best_checkpoint.pth") 
best_model = model #모델 넣어주세요
best_model.to(device)
best_model.load_state_dict(state_dict)
evaluate(best_model, testloader)
